# %% [markdown]
# #Trương Sĩ Thi Vũ
# #USTHBI8-189
# A part of this assignment is referenced from https://colab.research.google.com/drive/1FHn5GyqjO4nmE9Othcm1oJKOmIANecUY?fbclid=IwAR1BiC4zXJ7piEFVn2Tjza-k2vdOEEP08tnxza_SczISa2mR5PhSYj9nJ1k#scrollTo=QY4nkbfyjNMp

# %% [markdown]
# # Programming Assignment 4: Vietnamese Word Segmentation
#
# In this assignment, you will need to build a model for Vietnamese Word Segmentation.
#
# **Rules**:
#
# - You are freely to choose the approach, however, you are required to implement the model by yourself in the Google Colab.
# - **It is not allowed to use available Vietnamese Word Segmentation toolkits to do the assignment.**
#
# **Due date: April 10, 2020 (Friday)**

# %% [markdown]
# ## Vietnamese Word Segmentation
#
# In Vietnamese, one word may contain multiple syllables (e.g., 'học sinh'). Since there is not delimiter between words, in some applications, we may need to do word segmentation in the preprocessing step.
#
# The input of a Vietnamese Word Segmentation model is a sequence of syllables.
# (Note that, you may need to separate punctuations from words in the real scenerio). The output is a word-segmented text.
#
# Example:
#
# - Input: Nam hồn nhiên : " Tụi tôi xài tiền ngân hàng không à " .
# - Output: Nam hồn_nhiên : " Tụi tôi xài tiền ngân_hàng không à " .
#
# Similar as named-entity recognition, we can formalize the word segmentation task as a sequence labeling task with BI encoding scheme. We will predict if the tag of a syllable is B-W (begin of a word) or I-W (inside of a word). Tags for the sequence in the above example will be.
#
# ```
# Nam	B-W
# hồn	B-W
# nhiên	I-W
# :	B-W
# "	B-W
# Tụi	B-W
# tôi	B-W
# xài	B-W
# tiền	B-W
# ngân	B-W
# hàng	I-W
# không	B-W
# à	B-W
# "	B-W
# .	B-W
# ```
#
# We can choose Hidden Markov Models, Maximum Entropy Markov Models, or Conditional Random Fields to solve the problem. Please refer to previous lectures and assignments for details about those models.

# %% [markdown]
# ## Dataset
#
# You will use the training data in the file [train.txt](https://www.dl.dropboxusercontent.com/s/reor8jnqedk7svt/train.txt) to train your Vietnamese Word Segmentation Model and evaluate the model on the test data in the file [test.txt](https://www.dl.dropboxusercontent.com/s/zp635cd1zhofm62/test.txt) derived from VLSP 2013 Word Segmentation dataset.
#
# You can download the file using wget command.

# %%
# !rm -f train.txt
# !wget https://www.dl.dropboxusercontent.com/s/reor8jnqedk7svt/train.txt
# Out:
# --2020-04-10 14:24:39--  https://www.dl.dropboxusercontent.com/s/reor8jnqedk7svt/train.txt
# Resolving www.dl.dropboxusercontent.com (www.dl.dropboxusercontent.com)... 162.125.9.6, 2620:100:601f:6::a27d:906
# Connecting to www.dl.dropboxusercontent.com (www.dl.dropboxusercontent.com)|162.125.9.6|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5485066 (5.2M) [text/plain]
# Saving to: ‘train.txt’
#
# train.txt           100%[===================>]   5.23M  20.7MB/s    in 0.3s
#
# 2020-04-10 14:24:39 (20.7 MB/s) - ‘train.txt’ saved [5485066/5485066]

# %% [markdown]
# The training data contains 20000 sentences (sentences are separated by a blank line), and the test data contains 2000 sentences.

# %%
# !head -3 train.txt
# Out:
# Nam	B-W
# hồn	B-W
# nhiên	I-W

# %%
tagset = set()
with open('train.txt') as f:
    for line in f:
        if line.strip():
            wordtags = line.split()
            tag = wordtags[-1]
            tagset.add(tag)
print(tagset)
# Out:
# {'I-W', 'B-W'}

# %%
def load_data(input_file):    
    data = []
    with open(input_file, "r") as f:
        for line in f:
            line = line.strip()
            if line == "":
                continue
            wordtags = line.split()
            if len(wordtags) == 1:
                continue
            data.append((wordtags[0], wordtags[1]))
    return data

# %%
train_data = load_data('./train.txt')

# %%
train_data
# Out:
# [('Nam', 'B-W'),
#  ('hồn', 'B-W'),
#  ('nhiên', 'I-W'),
#  (':', 'B-W'),
#  ('"', 'B-W'),
#  ('Tụi', 'B-W'),
#  ('tôi', 'B-W'),
#  ('xài', 'B-W'),
#  ('tiền', 'B-W'),
#  ('ngân', 'B-W'),
#  ('hàng', 'I-W'),
#  ('không', 'B-W'),
#  ('à', 'B-W'),
#  ('"', 'B-W'),
#  ('.', 'B-W'),
#  ('Chỉ', 'B-W'),
#  ('trong', 'B-W'),
#  ('năm', 'B-W'),
#  ('2001', 'B-W'),
#  ('Tomb', 'B-W'),
#  ('Raider', 'I-W'),
#  ('đã', 'B-W'),
#  ('mang', 'B-W'),
#  ('về', 'B-W'),
#  ('cho', 'B-W'),
#  ('Hollywood', 'B-W'),
#  ('300', 'B-W'),
#  ('triệu', 'B-W'),
#  ('USD', 'B-W'),
#  ('(', 'B-W'),
#  ('dân', 'B-W'),
#  ('ghiền', 'B-W'),
#  ('xinê', 'B-W'),
#  ('ở', 'B-W'),
#  ('VN', 'B-W'),
#  ('cũng', 'B-W'),
#  ('đã', 'B-W'),
#  ('từng', 'B-W'),
#  ('lên', 'B-W'),
#  ('cơn', 'B-W'),
#  ('sốt', 'I-W'),
#  ('về', 'B-W'),
#  ('bộ', 'B-W'),
#  ('phim', 'B-W'),
#  ('này', 'B-W'),
#  (')', 'B-W'),
#  ('và', 'B-W'),
#  ('dòng', 'B-W'),
#  ('người', 'B-W'),
#  ('từ', 'B-W'),
#  ('khắp', 'B-W'),
#  ('thế', 'B-W'),
#  ('giới', 'I-W'),
#  ('đã', 'B-W'),
#  ('đổ', 'B-W'),
#  ('về', 'B-W'),
#  ('Siem', 'B-W'),
#  ('Reap', 'I-W'),
#  ('để', 'B-W'),
#  ('khám', 'B-W'),
#  ('phá', 'I-W'),
#  ('Angkor', 'B-W'),
#  (',', 'B-W'),
#  ('khám', 'B-W'),
#  ('phá', 'I-W'),
#  ('Ta', 'B-W'),
#  ('Prohm', 'I-W'),
#  ('.', 'B-W'),
#  ('Khác', 'B-W'),
#  ('với', 'B-W'),
#  ('UNESCO', 'B-W'),
#  (',', 'B-W'),
#  ('quan', 'B-W'),
#  ('điểm', 'I-W'),
#  ('cơ', 'B-W'),
#  ('bản', 'I-W'),
#  ('của', 'B-W'),
#  ('WTO', 'B-W'),
#  ('coi', 'B-W'),
#  ('giáo', 'B-W'),
#  ('dục', 'I-W'),
#  ('là', 'B-W'),
#  ('một', 'B-W'),
#  ('trong', 'B-W'),
#  ('12', 'B-W'),
#  ('ngành', 'B-W'),
#  ('dịch', 'B-W'),
#  ('vụ', 'I-W'),
#  ('thương', 'B-W'),
#  ('mại', 'I-W'),
#  ('thuộc', 'B-W'),
#  ('phạm', 'B-W'),
#  ('vi', 'I-W'),
#  ('điều', 'B-W'),
#  ('chỉnh', 'I-W'),
#  ('của', 'B-W'),
#  ('GATS', 'B-W'),
#  (';', 'B-W'),
#  ('dịch', 'B-W'),
#  ('vụ', 'I-W'),
#  ('này', 'B-W'),
#  ('cần', 'B-W'),
#  ('được', 'B-W'),
#  ('từng', 'B-W'),
#  ('bước', 'B-W'),
#  ('tự', 'B-W'),
#  ('do', 'I-W'),
#  ('hoá', 'I-W'),
#  ('thương', 'B-W'),
#  ('mại', 'I-W'),
#  ('thông', 'B-W'),
#  ('qua', 'I-W'),
#  ('đàm', 'B-W'),
#  ('phán', 'I-W'),
#  ('.', 'B-W'),
#  ('Làm', 'B-W'),
#  ('đất', 'B-W'),
#  ('có', 'B-W'),
#  ('tác', 'B-W'),
#  ('dụng', 'I-W'),
#  ('làm', 'B-W'),
#  ('cho', 'B-W'),
#  ('đất', 'B-W'),
#  ('tơi', 'B-W'),
#  ('xốp', 'B-W'),
#  (',', 'B-W'),
#  ('bằng', 'B-W'),
#  ('phẳng', 'I-W'),
#  (',', 'B-W'),
#  ('diệt', 'B-W'),
#  ('cỏ', 'B-W'),
#  ('dại', 'B-W'),
#  (',', 'B-W'),
#  ('mầm', 'B-W'),
#  ('mống', 'I-W'),
#  ('sâu', 'B-W'),
#  (',', 'B-W'),
#  ('bệnh', 'B-W'),
#  ('và', 'B-W'),
#  ('cải', 'B-W'),
#  ('tạo', 'I-W'),
#  ('đất', 'B-W'),
#  ('.', 'B-W'),
#  ('Sau', 'B-W'),
#  ('này', 'I-W'),
#  ('quy', 'B-W'),
#  ('tắc', 'I-W'),
#  ('Broughton', 'B-W'),
#  ('trở', 'B-W'),
#  ('thành', 'I-W'),
#  ('luật', 'B-W'),
#  ('thi', 'B-W'),
#  ('đấu', 'I-W'),
#  ('quyền', 'B-W'),
#  ('Anh', 'I-W'),
#  ('nhà', 'B-W'),
#  ('nghề', 'I-W'),
#  ('và', 'B-W'),
#  ('quy', 'B-W'),
#  ('tắc', 'I-W'),
#  ('Berry', 'B-W'),
#  ('trở', 'B-W'),
#  ('thành', 'I-W'),
#  ('luật', 'B-W'),
#  ('thi', 'B-W'),
#  ('đấu', 'I-W'),
#  ('quyền', 'B-W'),
#  ('Anh', 'I-W'),
#  ('nghiệp', 'B-W'),
#  ('dư', 'I-W'),
#  ('.', 'B-W'),
#  ('Tăng', 'B-W'),
#  ('cường', 'I-W'),
#  ('thanh', 'B-W'),
#  ('tra', 'I-W'),
#  (',', 'B-W'),
#  ('kiểm', 'B-W'),
#  ('tra', 'I-W'),
#  ('và', 'B-W'),
#  ('xử', 'B-W'),
#  ('lý', 'I-W'),
#  ('các', 'B-W'),
#  ('vi', 'B-W'),
#  ('phạm', 'I-W'),
#  ('về', 'B-W'),
#  ('qui', 'B-W'),
#  ('chế', 'I-W'),
#  ('kê', 'B-W'),
#  ('đơn', 'B-W'),
#  ('và', 'B-W'),
#  ('bán', 'B-W'),
#  ('thuốc', 'B-W'),
#  ('theo', 'B-W'),
#  ('đơn', 'B-W'),
#  (',', 'B-W'),
#  ('xử', 'B-W'),
#  ('lý', 'I-W'),
#  ('mạnh', 'B-W'),
#  ('các', 'B-W'),
#  ('hành', 'B-W'),
#  ('vi', 'I-W'),
#  ('ăn', 'B-W'),
#  ('chia', 'I-W'),
#  ('hoa', 'B-W'),
#  ('hồng', 'I-W'),
#  ('giữa', 'B-W'),
#  ('bác', 'B-W'),
#  ('sĩ', 'I-W'),
#  ('và', 'B-W'),
#  ('trình', 'B-W'),
#  ('dược', 'I-W'),
#  ('viên', 'I-W'),
#  ('...', 'B-W'),
#  ('cũng', 'B-W'),
#  ('là', 'B-W'),
#  ('các', 'B-W'),
#  ('kiến', 'B-W'),
#  ('nghị', 'I-W'),
#  ('của', 'B-W'),
#  ('TP', 'B-W'),
#  ('trong', 'B-W'),
#  ('thời', 'B-W'),
#  ('gian', 'I-W'),
#  ('tới', 'B-W'),
#  ('nhằm', 'B-W'),
#  ('làm', 'B-W'),
#  ('bình', 'B-W'),
#  ('ổn', 'I-W'),
#  ('giá', 'B-W'),
#  ('thuốc', 'B-W'),
#  ('.', 'B-W'),
#  ('Đà', 'B-W'),
#  ('Nẵng', 'I-W'),
#  ('cũng', 'B-W'),
#  ('đặt', 'B-W'),
#  ('ra', 'B-W'),
#  ('mục', 'B-W'),
#  ('tiêu', 'I-W'),
#  ('sẽ', 'B-W'),
#  ('xoá', 'B-W'),
#  ('hết', 'B-W'),
#  ('1.400', 'B-W'),
#  ('hộ', 'B-W'),
#  ('nghèo', 'B-W'),
#  ('đang', 'B-W'),
#  ('ở', 'B-W'),
#  ('nhà', 'B-W'),
#  ('tạm', 'B-W'),
#  ('còn', 'B-W'),
#  ('lại', 'B-W'),
#  ('vào', 'B-W'),
#  ('cuối', 'B-W'),
#  ('năm', 'B-W'),
#  ('2005', 'B-W'),
#  ('.', 'B-W'),
#  ('TTO', 'B-W'),
#  ('-', 'B-W'),
#  ('Tối', 'B-W'),
#  ('nay', 'B-W'),
#  (',', 'B-W'),
#  ('16', 'B-W'),
#  ('-', 'B-W'),
#  ('3', 'B-W'),
#  (',', 'B-W'),
#  ('tại', 'B-W'),
#  ('nhà', 'B-W'),
#  ('triển', 'B-W'),
#  ('lãm', 'I-W'),
#  ('Vân', 'B-W'),
#  ('Canh', 'I-W'),
#  (',', 'B-W'),
#  ('22', 'B-W'),
#  ('bis', 'B-W'),
#  (',', 'B-W'),
#  ('rue', 'B-W'),
#  ('Béranger', 'B-W'),
#  (',', 'B-W'),
#  ('92240', 'B-W'),
#  ('Malakoff', 'B-W'),
#  (',', 'B-W'),
#  ('Pháp', 'B-W'),
#  ('diễn', 'B-W'),
#  ('ra', 'B-W'),
#  ('triển', 'B-W'),
#  ('lãm', 'I-W'),
#  ('về', 'B-W'),
#  ('trẻ', 'B-W'),
#  ('em', 'I-W'),
#  ('Việt', 'B-W'),
#  ('Nam', 'I-W'),
#  ('bị', 'B-W'),
#  ('nhiễm', 'B-W'),
#  ('độc', 'I-W'),
#  ('dioxin', 'B-W'),
#  ('với', 'B-W'),
#  ('chủ', 'B-W'),
#  ('đề', 'I-W'),
#  ('"', 'B-W'),
#  ('Chất', 'B-W'),
#  ('dioxin', 'B-W'),
#  ('vẫn', 'B-W'),
#  ('còn', 'B-W'),
#  ('đang', 'B-W'),
#  ('gây', 'B-W'),
#  ('tác', 'B-W'),
#  ('hại', 'I-W'),
#  ('tại', 'B-W'),
#  ('Việt', 'B-W'),
#  ('Nam', 'I-W'),
#  ('"', 'B-W'),
#  ('.', 'B-W'),
#  ('Mọi', 'B-W'),
#  ('người', 'B-W'),
#  ('ngậm', 'B-W'),
#  ('chì', 'B-W'),
#  ('cả', 'B-W'),
#  ('mấy', 'B-W'),
#  ('chục', 'B-W'),
#  ('năm', 'B-W'),
#  ('ni', 'B-W'),
#  ('có', 'B-W'),
#  ('hề', 'B-W'),
#  ('chi', 'B-W'),
#  ('mô', 'B-W'),
#  ('...', 'B-W'),
#  ('"', 'B-W'),
#  ('.', 'B-W'),
#  ('Tôi', 'B-W'),
#  ('cũng', 'B-W'),
#  ('có', 'B-W'),
#  ('mặt', 'I-W'),
#  ('trong', 'B-W'),
#  ('phần', 'B-W'),
#  ('lớn', 'I-W'),
#  ('những', 'B-W'),
#  ('buổi', 'B-W'),
#  ('chầu', 'B-W'),
#  ('chực', 'I-W'),
#  ('đó', 'B-W'),
#  ('.', 'B-W'),
#  ('Ngoài', 'B-W'),
#  ('các', 'B-W'),
#  ('kiểu', 'B-W'),
#  ('thảm', 'B-W'),
#  ('thực', 'I-W'),
#  ('vật', 'I-W'),
#  ('tự', 'B-W'),
#  ('nhiên', 'I-W'),
#  (',', 'B-W'),
#  ('thảm', 'B-W'),
#  ('thực', 'I-W'),
#  ('vật', 'I-W'),
#  ('nhân', 'B-W'),
#  ('tác', 'I-W'),
#  ('cũng', 'B-W'),
#  ('chiếm', 'B-W'),
#  ('một', 'B-W'),
#  ('diện', 'B-W'),
#  ('tích', 'I-W'),
#  ('tương', 'B-W'),
#  ('đối', 'I-W'),
#  ('lớn', 'B-W'),
#  (',', 'B-W'),
#  ('bao', 'B-W'),
#  ('gồm', 'I-W'),
#  ('các', 'B-W'),
#  ('cây', 'B-W'),
#  ('lương', 'I-W'),
#  ('thực', 'I-W'),
#  (',', 'B-W'),
#  ('cây', 'B-W'),
#  ('thực', 'I-W'),
#  ('phẩm', 'I-W'),
#  (',', 'B-W'),
#  ('cây', 'B-W'),
#  ('bóng', 'I-W'),
#  ('mát', 'I-W'),
#  (',', 'B-W'),
#  ('cây', 'B-W'),
#  ('ăn', 'I-W'),
#  ('quả', 'I-W'),
#  ('và', 'B-W'),
#  ('cây', 'B-W'),
#  ('cảnh', 'I-W'),
#  ('.', 'B-W'),
#  ('Đương', 'B-W'),
#  ('nhiên', 'I-W'),
#  ('là', 'B-W'),
#  ('hiện', 'B-W'),
#  ('nay', 'I-W'),
#  (',', 'B-W'),
#  ('giới', 'B-W'),
#  ('kinh', 'B-W'),
#  ('doanh', 'I-W'),
#  ('châu', 'B-W'),
#  ('Âu', 'I-W'),
#  ('đang', 'B-W'),
#  ('bị', 'B-W'),
#  ('thu', 'B-W'),
#  ('hút', 'I-W'),
#  ('nhiều', 'B-W'),
#  ('vào', 'B-W'),
#  ('thị', 'B-W'),
#  ('trường', 'I-W'),
#  ('Trung', 'B-W'),
#  ('Quốc', 'I-W'),
#  ('và', 'B-W'),
#  ('Ấn', 'B-W'),
#  ('Độ', 'I-W'),
#  ('.', 'B-W'),
#  ('Ngày', 'B-W'),
#  ('30-10-2003', 'B-W'),
#  (',', 'B-W'),
#  ('PV', 'B-W'),
#  ('Tuổi', 'B-W'),
#  ('Trẻ', 'I-W'),
#  ('đã', 'B-W'),
#  ('đến', 'B-W'),
#  ('Đội', 'B-W'),
#  ('QLĐKX', 'B-W'),
#  ('&', 'B-W'),
#  ('LX', 'B-W'),
#  (',', 'B-W'),
#  ('282', 'B-W'),
#  ('Nơ', 'B-W'),
#  ('Trang', 'I-W'),
#  ('Long', 'I-W'),
#  ('để', 'B-W'),
#  ('tìm', 'B-W'),
#  ('hiểu', 'I-W'),
#  ('.', 'B-W'),
#  ('TP.', 'B-W'),
#  ('HCM', 'B-W'),
#  (':', 'B-W'),
#  ('xây', 'B-W'),
#  ('dựng', 'I-W'),
#  ('2', 'B-W'),
#  ('cầu', 'B-W'),
#  ('vượt', 'I-W'),
#  ('bộ', 'B-W'),
#  ('hành', 'I-W'),
#  ('và', 'B-W'),
#  ('chăm', 'B-W'),
#  ('bẵm', 'I-W'),
#  ('cho', 'B-W'),
#  ('những', 'B-W'),
#  ('mầm', 'B-W'),
#  ('cây', 'B-W'),
#  ('lớn', 'B-W'),
#  ('.', 'B-W'),
#  ('Đến', 'B-W'),
#  ('nay', 'B-W'),
#  ('gần', 'B-W'),
#  ('năm', 'B-W'),
#  ('năm', 'B-W'),
#  ('sau', 'B-W'),
#  ('khi', 'B-W'),
#  ('di', 'B-W'),
#  ('dời', 'I-W'),
#  ('căn', 'B-W'),
#  ('nhà', 'B-W'),
#  ('vẫn', 'B-W'),
#  ('ổn', 'B-W'),
#  ('định', 'I-W'),
#  ('không', 'B-W'),
#  ('có', 'B-W'),
#  ('biểu', 'B-W'),
#  ('hiện', 'I-W'),
#  ('lún', 'B-W'),
#  (',', 'B-W'),
#  ('nứt', 'B-W'),
#  ('.', 'B-W'),
#  ('Xin', 'B-W'),
#  ('chân', 'B-W'),
#  ('thành', 'I-W'),
#  ('cảm', 'B-W'),
#  ('ơn', 'I-W'),
#  ('tiến', 'B-W'),
#  ('sĩ', 'I-W'),
#  ('và', 'B-W'),
#  ('các', 'B-W'),
#  ('bạn', 'B-W'),
#  ('đồng', 'B-W'),
#  ('nghiệp', 'I-W'),
#  ('.', 'B-W'),
#  ('UBND', 'B-W'),
#  ('TP', 'B-W'),
#  ('cũng', 'B-W'),
#  ('chỉ', 'B-W'),
#  ('đạo', 'I-W'),
#  ('giao', 'B-W'),
#  ('Sở', 'B-W'),
#  ('Xây', 'B-W'),
#  ('dựng', 'I-W'),
#  ('tiếp', 'B-W'),
#  ('tục', 'I-W'),
#  ('theo', 'B-W'),
#  ('dõi', 'I-W'),
#  (',', 'B-W'),
#  ('đôn', 'B-W'),
#  ('đốc', 'I-W'),
#  ('Công', 'B-W'),
#  ('ty', 'I-W'),
#  ('Thanh', 'B-W'),
#  ('niên', 'I-W'),
#  ('xung', 'B-W'),
#  ('phong', 'I-W'),
#  (',', 'B-W'),
#  ('các', 'B-W'),
#  ('cơ', 'B-W'),
#  ('quan', 'I-W'),
#  ('liên', 'B-W'),
#  ('quan', 'I-W'),
#  ('để', 'B-W'),
#  ('yêu', 'B-W'),
#  ('cầu', 'I-W'),
#  ('thực', 'B-W'),
#  ('hiện', 'I-W'),
#  ('thủ', 'B-W'),
#  ('tục', 'I-W'),
#  ('thu', 'B-W'),
#  ('hồi', 'I-W'),
#  ('tám', 'B-W'),
#  ('căn', 'B-W'),
#  ('hộ', 'I-W'),
#  ('lầu', 'B-W'),
#  ('14', 'B-W'),
#  ('lô', 'B-W'),
#  ('C', 'B-W'),
#  ('chung', 'B-W'),
#  ('cư', 'I-W'),
#  ('Ngô', 'B-W'),
#  ('Tất', 'I-W'),
#  ('Tố', 'I-W'),
#  ('đã', 'B-W'),
#  ('bố', 'B-W'),
#  ('trí', 'I-W'),
#  ('tạm', 'B-W'),
#  ('cư', 'I-W'),
#  ('cho', 'B-W'),
#  ('các', 'B-W'),
#  ('hộ', 'B-W'),
#  ('dân', 'B-W'),
#  ('.', 'B-W'),
#  ('Lọ', 'B-W'),
#  ('muối', 'B-W'),
#  (',', 'B-W'),
#  ('chai', 'B-W'),
#  ('mắm', 'B-W'),
#  (',', 'B-W'),
#  ('hộp', 'B-W'),
#  ('gia', 'B-W'),
#  ('vị', 'I-W'),
#  ('...', 'B-W'),
#  ('đã', 'B-W'),
#  ('không', 'B-W'),
#  ('để', 'B-W'),
#  ('chỗ', 'B-W'),
#  ('cũ', 'B-W'),
#  ('.', 'B-W'),
#  ('Tuy', 'B-W'),
#  ('nhiên', 'I-W'),
#  ('tình', 'B-W'),
#  ('hình', 'I-W'),
#  ('an', 'B-W'),
#  ('ninh', 'I-W'),
#  ('trật', 'B-W'),
#  ('tự', 'I-W'),
#  ('tại', 'B-W'),
#  ('các', 'B-W'),
#  ('bãi', 'B-W'),
#  ('tắm', 'I-W'),
#  ('và', 'B-W'),
#  ('điểm', 'B-W'),
#  ('tham', 'B-W'),
#  ('quan', 'I-W'),
#  ('ở', 'B-W'),
#  ('Vũng', 'B-W'),
#  ('Tàu', 'I-W'),
#  ('ngày', 'B-W'),
#  ('2', 'B-W'),
#  ('-', 'B-W'),
#  ('9', 'B-W'),
#  ('năm', 'B-W'),
#  ('nay', 'B-W'),
#  ('đã', 'B-W'),
#  ('được', 'B-W'),
#  ('cải', 'B-W'),
#  ('thiện', 'I-W'),
#  ('đáng', 'B-W'),
#  ('kể', 'I-W'),
#  (',', 'B-W'),
#  ('nạn', 'B-W'),
#  ('hàng', 'B-W'),
#  ('rong', 'B-W'),
#  ('chèo', 'B-W'),
#  ('kéo', 'I-W'),
#  ('giảm', 'B-W'),
#  ('hẳn', 'B-W'),
#  ('.', 'B-W'),
#  ('Nguyên', 'B-W'),
#  ('nhân', 'I-W'),
#  ('do', 'B-W'),
#  ('ăn', 'B-W'),
#  ('rau', 'B-W'),
#  (',', 'B-W'),
#  ('quả', 'B-W'),
#  ('(', 'B-W'),
#  ('trái', 'B-W'),
#  (')', 'B-W'),
#  ('có', 'B-W'),
#  ('thuốc', 'B-W'),
#  ('trừ', 'I-W'),
#  ('sâu', 'I-W'),
#  ('không', 'B-W'),
#  ('rửa', 'B-W'),
#  ('sạch', 'B-W'),
#  (',', 'B-W'),
#  ('do', 'B-W'),
#  ('không', 'B-W'),
#  ('đảm', 'B-W'),
#  ('bảo', 'I-W'),
#  ('an', 'B-W'),
#  ('toàn', 'I-W'),
#  ('khi', 'B-W'),
#  ('sử', 'B-W'),
#  ('dụng', 'I-W'),
#  ('thuốc', 'B-W'),
#  ('và', 'B-W'),
#  ('phun', 'B-W'),
#  ('thuốc', 'B-W'),
#  ('không', 'B-W'),
#  ('đúng', 'B-W'),
#  ('kĩ', 'B-W'),
#  ('thuật', 'I-W'),
#  ('.', 'B-W'),
#  ('Năm', 'B-W'),
#  ('ngoái', 'I-W'),
#  (',', 'B-W'),
#  ('khi', 'B-W'),
#  ('đoàn', 'B-W'),
#  ('công', 'B-W'),
#  ('tác', 'I-W'),
#  ('của', 'B-W'),
#  ('Sở', 'B-W'),
#  ('Lao', 'B-W'),
#  ('động', 'I-W'),
#  ('-', 'B-W'),
#  ('thương', 'B-W'),
#  ('binh', 'I-W'),
#  ('và', 'B-W'),
#  ('xã', 'B-W'),
#  ('hội', 'I-W'),
#  ('TP.', 'B-W'),
#  ('HCM', 'B-W'),
#  ('về', 'B-W'),
#  ('làm', 'B-W'),
#  ('việc', 'I-W'),
#  ('với', 'B-W'),
#  ('xã', 'B-W'),
#  ('về', 'B-W'),
#  ('vấn', 'B-W'),
#  ('đề', 'I-W'),
#  ('TELT', 'B-W'),
#  (',', 'B-W'),
#  ('ông', 'B-W'),
#  ('đã', 'B-W'),
#  ('yêu', 'B-W'),
#  ('cầu', 'I-W'),
#  ('lãnh', 'B-W'),
#  ('đạo', 'I-W'),
#  ('sở', 'B-W'),
#  ('giúp', 'B-W'),
#  ('đỡ', 'I-W'),
#  ('và', 'B-W'),
#  ('tạo', 'B-W'),
#  ('điều', 'B-W'),
#  ('kiện', 'I-W'),
#  ('để', 'B-W'),
#  ('cháu', 'B-W'),
#  ('Lê', 'B-W'),
#  ('Đình', 'I-W'),
#  ('Thuấn', 'I-W'),
#  ('(', 'B-W'),
#  ('thôn', 'B-W'),
#  ('7', 'B-W'),
#  (')', 'B-W'),
#  (',', 'B-W'),
#  ('Tô', 'B-W'),
#  ('Văn', 'I-W'),
#  ('Quý', 'I-W'),
#  ('(', 'B-W'),
#  ('thôn', 'B-W'),
#  ('2', 'B-W'),
#  (')', 'B-W'),
#  ('...', 'B-W'),
#  ('lang', 'B-W'),
#  ('thang', 'I-W'),
#  ('nhiều', 'B-W'),
#  ('năm', 'B-W'),
#  ('trong', 'B-W'),
#  ('thành', 'B-W'),
#  ('phố', 'I-W'),
#  ('trở', 'B-W'),
#  ('về', 'B-W'),
#  ('.', 'B-W'),
#  ('Theo', 'B-W'),
#  ('thông', 'B-W'),
#  ('tin', 'I-W'),
#  ('chúng', 'B-W'),
#  ('tôi', 'I-W'),
#  ('nắm', 'B-W'),
#  ('được', 'B-W'),
#  (',', 'B-W'),
#  ('trước', 'B-W'),
#  ('đây', 'I-W'),
#  ('một', 'B-W'),
#  ('BS', 'B-W'),
#  ('của', 'B-W'),
#  ('BV', 'B-W'),
#  ('tư', 'B-W'),
#  ('B', 'B-W'),
#  ('...', 'B-W'),
#  ('đã', 'B-W'),
#  ('mắc', 'B-W'),
#  ('nợ', 'B-W'),
#  ('cả', 'B-W'),
#  ('100', 'B-W'),
#  ('triệu', 'B-W'),
#  ('đồng', 'B-W'),
#  ('của', 'B-W'),
#  ('một', 'B-W'),
#  ('CT', 'B-W'),
#  ('do', 'B-W'),
#  ('nhận', 'B-W'),
#  ('hoa', 'B-W'),
#  ('hồng', 'I-W'),
#  ('nhiều', 'B-W'),
#  ('mà', 'B-W'),
#  ('không', 'B-W'),
#  ('kê', 'B-W'),
#  ('đủ', 'B-W'),
#  ('toa', 'B-W'),
#  ('mặt', 'B-W'),
#  ('hàng', 'I-W'),
#  ('Alsuperan', 'B-W'),
#  ('.', 'B-W'),
#  ('Đáng', 'B-W'),
#  ('chú', 'B-W'),
#  ('ý', 'I-W'),
#  ('là', 'B-W'),
#  ('trong', 'B-W'),
#  ('số', 'B-W'),
#  ('47', 'B-W'),
#  ('người', 'B-W'),
#  ('không', 'B-W'),
#  ('cho', 'B-W'),
#  ('là', 'B-W'),
#  ('vi', 'B-W'),
#  ('phạm', 'I-W'),
#  (',', 'B-W'),
#  ('có', 'B-W'),
#  ('8', 'B-W'),
#  ('người', 'B-W'),
#  ('sinh', 'B-W'),
#  ('viên', 'I-W'),
#  (',', 'B-W'),
#  ('là', 'B-W'),
#  ('nhóm', 'B-W'),
#  ('người', 'B-W'),
#  ('ít', 'B-W'),
#  ('nhiều', 'I-W'),
#  ('có', 'B-W'),
#  ('được', 'B-W'),
#  ('học', 'B-W'),
#  ('về', 'B-W'),
#  ('vấn', 'B-W'),
#  ('đề', 'I-W'),
#  ('này', 'B-W'),
#  (',', 'B-W'),
#  ('chứng', 'B-W'),
#  ('tỏ', 'I-W'),
#  ('SHTT', 'B-W'),
#  ('còn', 'B-W'),
#  ('là', 'B-W'),
#  ('vấn', 'B-W'),
#  ('đề', 'I-W'),
#  ('nan', 'B-W'),
#  ('giải', 'I-W'),
#  ('ở', 'B-W'),
#  ('Việt', 'B-W'),
#  ('Nam', 'I-W'),
#  ('trong', 'B-W'),
#  ('thời', 'B-W'),
#  ('gian', 'I-W'),
#  ('tới', 'B-W'),
#  ('.', 'B-W'),
#  ('Từ', 'B-W'),
#  ('đầu', 'B-W'),
#  ('năm', 'B-W'),
#  ('2003', 'B-W'),
#  (',', 'B-W'),
#  ('trên', 'B-W'),
#  ('tuyến', 'B-W'),
#  ('kênh', 'B-W'),
#  ('Nhiêu', 'B-W'),
#  ('Lộc', 'I-W'),
#  ('-', 'B-W'),
#  ('Thị', 'B-W'),
#  ('Nghè', 'I-W'),
#  ('chín', 'B-W'),
#  ('cây', 'I-W'),
#  ('cầu', 'B-W'),
#  ('được', 'B-W'),
#  ('đồng', 'B-W'),
#  ('loạt', 'I-W'),
#  ('khởi', 'B-W'),
#  ('công', 'I-W'),
#  (',', 'B-W'),
#  ('theo', 'B-W'),
#  ('dự', 'B-W'),
#  ('kiến', 'I-W'),
#  ('đến', 'B-W'),
#  ('cuối', 'B-W'),
#  ('năm', 'B-W'),
#  ('2003', 'B-W'),
#  ('có', 'B-W'),
#  ('ít', 'B-W'),
#  ('nhất', 'I-W'),
#  ('sáu', 'B-W'),
#  ('cây', 'B-W'),
#  ('cầu', 'B-W'),
#  ('hoàn', 'B-W'),
#  ('thành', 'I-W'),
#  ('.', 'B-W'),
#  ('Cũng', 'B-W'),
#  ('có', 'B-W'),
#  ('nghĩa', 'B-W'),
#  ('là', 'I-W'),
#  ('từ', 'B-W'),
#  ('nay', 'B-W'),
#  ('trở', 'B-W'),
#  ('về', 'B-W'),
#  ('sau', 'B-W'),
#  ('Sở', 'B-W'),
#  ('GTVT', 'B-W'),
#  ('Đồng', 'B-W'),
#  ('Nai', 'I-W'),
#  ('sẽ', 'B-W'),
#  ('không', 'B-W'),
#  ('có', 'B-W'),
#  ('bất', 'B-W'),
#  ('cứ', 'I-W'),
#  ('trách', 'B-W'),
#  ('nhiệm', 'I-W'),
#  ('gì', 'B-W'),
#  ('với', 'B-W'),
#  ('chiếc', 'B-W'),
#  ('cầu', 'B-W'),
#  ('này', 'B-W'),
#  (',', 'B-W'),
#  ('và', 'B-W'),
#  ('cả', 'B-W'),
#  ('trong', 'B-W'),
#  ('trường', 'B-W'),
#  ('hợp', 'I-W'),
#  ('xấu', 'B-W'),
#  ('nhất', 'B-W'),
#  ('xảy', 'B-W'),
#  ('ra', 'B-W'),
#  ('thì', 'B-W'),
#  ('Sở', 'B-W'),
#  ('GTVT', 'B-W'),
#  ('cũng', 'B-W'),
#  ('chỉ', 'B-W'),
#  ('...', 'B-W'),
#  ('được', 'B-W'),
#  ('đứng', 'B-W'),
#  ('nhìn', 'B-W'),
#  ('?', 'B-W'),
#  ('Trước', 'B-W'),
#  ('tháng', 'B-W'),
#  ('11-2004', 'B-W'),
#  (',', 'B-W'),
#  ('cảnh', 'B-W'),
#  ('sát', 'I-W'),
#  ('bắt', 'B-W'),
#  ('được', 'B-W'),
#  ('gái', 'B-W'),
#  ('tại', 'B-W'),
#  ('các', 'B-W'),
#  ('khu', 'B-W'),
#  ('nhà', 'B-W'),
#  ('thổ', 'I-W'),
#  ('là', 'B-W'),
#  ('trục', 'B-W'),
#  ('xuất', 'I-W'),
#  ('ngay', 'B-W'),
#  (',', 'B-W'),
#  ('nay', 'B-W'),
#  ('theo', 'B-W'),
#  ('đạo', 'B-W'),
#  ('luật', 'I-W'),
#  ('mới', 'B-W'),
#  ('tại', 'B-W'),
#  ('Hàn', 'B-W'),
#  (',', 'B-W'),
#  ('gái', 'B-W'),
#  ('bị', 'B-W'),
#  ('bắt', 'B-W'),
#  ('tại', 'B-W'),
#  ('các', 'B-W'),
#  ('khu', 'B-W'),
#  ('nhà', 'B-W'),
#  ('thổ', 'I-W'),
#  ('có', 'B-W'),
#  ('thể', 'I-W'),
#  ('bị', 'B-W'),
#  ('tù', 'B-W'),
#  ('10', 'B-W'),
#  ('năm', 'B-W'),
#  ('hoặc', 'B-W'),
#  ('phải', 'B-W'),
#  ('đóng', 'B-W'),
#  ('phạt', 'B-W'),
#  ('100', 'B-W'),
#  ('triệu', 'B-W'),
#  ('won', 'B-W'),
#  (',', 'B-W'),
#  ('tương', 'B-W'),
#  ('đương', 'I-W'),
#  ('87.000', 'B-W'),
#  ('USD', 'B-W'),
#  ('"', 'B-W'),
#  ('.', 'B-W'),
#  ('Trong', 'B-W'),
#  ('nhà', 'B-W'),
#  ('có', 'B-W'),
#  ('chiếc', 'B-W'),
#  ('bóng', 'B-W'),
#  ('điện', 'I-W'),
#  ('duy', 'B-W'),
#  ('nhất', 'I-W'),
#  ('thì', 'B-W'),
#  ('được', 'B-W'),
#  ('lắp', 'B-W'),
#  ('ngay', 'B-W'),
#  ('trên', 'B-W'),
#  ('giường', 'B-W'),
#  ('ông', 'B-W'),
#  ('nằm', 'B-W'),
#  ('.', 'B-W'),
#  ('Mua', 'B-W'),
#  ('chiếc', 'B-W'),
#  ('vé', 'B-W'),
#  ('Huế', 'B-W'),
#  ('-', 'B-W'),
#  ('Qui', 'B-W'),
#  ('Nhơn', 'I-W'),
#  ('với', 'B-W'),
#  ('giá', 'B-W'),
#  ('80.000', 'B-W'),
#  ('đ', 'B-W'),
#  ('ở', 'B-W'),
#  ('bến', 'B-W'),
#  ('xe', 'I-W'),
#  ('phía', 'B-W'),
#  ('nam', 'B-W'),
#  ('TP', 'B-W'),
#  ('Huế', 'B-W'),
#  (',', 'B-W'),
#  ('đang', 'B-W'),
#  ('đứng', 'B-W'),
#  ('lơ', 'B-W'),
#  ('ngơ', 'I-W'),
#  ('ở', 'B-W'),
#  ('bến', 'B-W'),
#  (',', 'B-W'),
#  ('một', 'B-W'),
#  ('tài', 'B-W'),
#  ('xế', 'I-W'),
#  ('trẻ', 'B-W'),
#  ('đã', 'B-W'),
#  ('hỏi', 'B-W'),
#  ('chúng', 'B-W'),
#  ('tôi', 'I-W'),
#  ('rất', 'B-W'),
#  ('ân', 'B-W'),
#  ('cần', 'I-W'),
#  (':', 'B-W'),
#  ('"', 'B-W'),
#  ('Anh', 'B-W'),
#  ('đi', 'B-W'),
#  ('xe', 'B-W'),
#  ('Thuận', 'B-W'),
#  ('Thảo', 'I-W'),
#  ('phải', 'B-W'),
#  ('không', 'B-W'),
#  ('?', 'B-W'),
#  ('Anh', 'B-W'),
#  ...]

# %%
#Copied from professor Minh's code
def feature_func(word, previous_tag):
    
    feat_vec = {}

    # Indicator (boolean) features
    # Nguyễn Văn A
    if word[0].isupper():
        feat_vec['is_first_capital'] = 1
    # IBM
    if int(word.upper() == word):
        feat_vec['is_all_caps'] = 1
    if word.lower() == word:
        feat_vec['is_all_lower'] = 1
    if '-' in word:
        feat_vec['has_hyphen'] = 1
    # 1, 2, 345
    if word.isdigit():
        feat_vec['is_numeric'] = 1
    # aBC
    if word[1:].lower() != word[1:]:
        feat_vec['capitals_inside'] = 1

    # Lexical features
    feat_vec['word'] = word
    feat_vec['word.lower()'] = word.lower()
    feat_vec['prefix_1'] = word[0]
    feat_vec['prefix_2'] = word[:2]
    feat_vec['prefix_3'] = word[:3]
    feat_vec['prefix_4'] = word[:4]
    feat_vec['suffix_1'] = word[-1]
    feat_vec['suffix_2'] = word[-2:]
    feat_vec['suffix_3'] = word[-3:]
    feat_vec['suffix_4'] = word[-4:]

    # Tag feature
    feat_vec['previous_tag'] = previous_tag

    return feat_vec

# %%
training_instances = []
training_labels = []
i = 0
for (word, tag) in train_data:
    if i == 0:
        previous_tag = '<bos>'
    else:
        previous_tag = train_data[i-1][1]
    training_instances.append((word, previous_tag))
    training_labels.append(tag)
    i += 1

# %%
list(zip(training_instances[:10], training_labels[:10]))
# Out:
# [(('Nam', '<bos>'), 'B-W'),
#  (('hồn', 'B-W'), 'B-W'),
#  (('nhiên', 'B-W'), 'I-W'),
#  ((':', 'I-W'), 'B-W'),
#  (('"', 'B-W'), 'B-W'),
#  (('Tụi', 'B-W'), 'B-W'),
#  (('tôi', 'B-W'), 'B-W'),
#  (('xài', 'B-W'), 'B-W'),
#  (('tiền', 'B-W'), 'B-W'),
#  (('ngân', 'B-W'), 'B-W')]

# %%
feature_func('cá', 'B-W')
# Out:
# {'is_all_lower': 1,
#  'prefix_1': 'c',
#  'prefix_2': 'cá',
#  'prefix_3': 'cá',
#  'prefix_4': 'cá',
#  'previous_tag': 'B-W',
#  'suffix_1': 'á',
#  'suffix_2': 'cá',
#  'suffix_3': 'cá',
#  'suffix_4': 'cá',
#  'word': 'cá',
#  'word.lower()': 'cá'}

# %%
train_feat_vecs = [feature_func(word, tag) for word, tag in training_instances]

# %%
from sklearn.feature_extraction import DictVectorizer

vectorizer = DictVectorizer()
X_train = vectorizer.fit_transform(train_feat_vecs)
X_train.shape
# Out:
# (581893, 63776)

# %%
from sklearn.linear_model import LogisticRegression

maxent = LogisticRegression(max_iter=500)
maxent.fit(X_train, training_labels)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=500,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
target_classes = maxent.classes_.tolist()
label2id = {k: v for v, k in enumerate(target_classes)}
print(label2id)
# Out:
# {'B-W': 0, 'I-W': 1}

# %%
maxent.predict(vectorizer.transform([feature_func('sinh', 'B-W')]))
# Out:
# array(['I-W'], dtype='<U3')

# %%
import numpy as np

np.argmax(maxent.predict_proba(vectorizer.transform([feature_func('học', 'B-W')])))
# Out:
# 1

# %% [markdown]
# ##Algorithm based on viterbi

# %%
def get_negative_log_proba(word, previous_tag):
    prob = maxent.predict_log_proba(vectorizer.transform([feature_func(word, previous_tag)]))
    return -prob[0]

def decode(words):
    """Get the tag sequence for a word sequence
    """
    l = len(words)
    best_score = {}
    best_edge = {}
    best_score[('0 <bos>')] = 0 
    best_edge[('0 <bos>')] = None

    # Forward Step
    w1 = words[0]
    neg_log_proba1 = get_negative_log_proba(w1, '<bos>')
    for tag in target_classes:
        idx = label2id[tag]
        best_score[str(1) + ' ' + tag] = neg_log_proba1[idx]
        best_edge[str(1) + ' ' + tag] = '0 <bos>'
    
    for i in range(1, l):
        w = words[i]
        for prev_tag in target_classes:
            neg_log_proba = get_negative_log_proba(w, prev_tag)
            for next_tag in target_classes: 
                idx = label2id[next_tag]
                if str(i) + ' ' + prev_tag in best_score:
                    score = best_score[str(i) + ' ' + prev_tag] + neg_log_proba[idx]

                    if str(i + 1) + " " + next_tag not in best_score or best_score[str(i + 1) + " " + next_tag] > score:
                        best_score[str(i + 1) + " " + next_tag] = score
                        best_edge[str(i + 1) + " " + next_tag] = str(i) + " " + prev_tag
    
    for prev in target_classes:
        if str(l) + ' ' + prev in best_score:
            score = best_score[str(l) + ' ' + prev]
            if str(l+1) + ' ' + '<eos>' not in best_score or best_score[str(l+1) + ' <eos>'] > score:
                best_score[str(l+1) + ' <eos>'] = score
                best_edge[str(l+1) + ' <eos>'] = str(l) + ' ' + prev
    
    # Backward Step
    tags = []
    next_edge = best_edge[str(l + 1) + " " + "<eos>"]
    while next_edge != "0 <bos>":
        position, tag= next_edge.split()
        tags.append(tag)
        next_edge = best_edge[next_edge]
    tags.reverse()
    return tags

# %%
print(viterbi('Tôi là giảng viên đại học'.split(' ')))
print(viterbi(['Học', 'sinh', 'học', '.']))
# Out:
# ['B-W', 'B-W', 'B-W', 'I-W', 'B-W', 'I-W']
# ['B-W', 'I-W', 'B-W', 'B-W']

# %% [markdown]
# ## Evaluation Measures
#
# - P(recision): (number of words correctly segmented)/(number of words in the system output)
# - R(ecall): (number of words correctly segmented)/(number of words in the reference corpus)
# - F1 measure = 2*P*R/(P+R)

# %% [markdown]
# ### Evaluation code
#
# You will use the following code for your evaluation. The input of the function is two files:
#
# - test_file is the file with gold word segmentation.
# - output_file is the the output file which is generated by your system. output_file and test_file have the same format.
#
# The function will return precision, recall, and f1 score.
#
# We will use the package [seqeval](https://github.com/chakki-works/seqeval) for evaluation.

# %%
# !pip install seqeval[cpu]
# Out:
# Requirement already satisfied: seqeval[cpu] in /usr/local/lib/python3.6/dist-packages (0.0.12)
# Requirement already satisfied: Keras>=2.2.4 in /usr/local/lib/python3.6/dist-packages (from seqeval[cpu]) (2.2.5)
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/lib/python3.6/dist-packages (from seqeval[cpu]) (1.18.2)
# Requirement already satisfied: tensorflow>=1.13.1; extra == "cpu" in /usr/local/lib/python3.6/dist-packages (from seqeval[cpu]) (2.2.0rc2)
# Requirement already satisfied: keras-preprocessing>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from Keras>=2.2.4->seqeval[cpu]) (1.1.0)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.6/dist-packages (from Keras>=2.2.4->seqeval[cpu]) (1.4.1)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from Keras>=2.2.4->seqeval[cpu]) (2.10.0)
# Requirement already satisfied: keras-applications>=1.0.8 in /usr/local/lib/python3.6/dist-packages (from Keras>=2.2.4->seqeval[cpu]) (1.0.8)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from Keras>=2.2.4->seqeval[cpu]) (1.12.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from Keras>=2.2.4->seqeval[cpu]) (3.13)
# Requirement already satisfied: google-pasta>=0.1.8 in /usr/local/lib/python3.6/dist-packages (from tensorflow>=1.13.1; extra == "cpu"->seqeval[cpu]) (0.2.0)
# Requirement already satisfied: wheel>=0.26; python_version >= "3" in /usr/local/lib/python3.6/dist-packages (from tensorflow>=1.13.1; extra == "cpu"->seqeval[cpu]) (0.34.2)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow>=1.13.1; extra == "cpu"->seqeval[cpu]) (1.27.2)
# Requirement already satisfied: tensorflow-estimator<2.3.0,>=2.2.0rc0 in /usr/local/lib/python3.6/dist-packages (from tensorflow>=1.13.1; extra == "cpu"->seqeval[cpu]) (2.2.0rc0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow>=1.13.1; extra == "cpu"->seqeval[cpu]) (3.2.0)
# Requirement already satisfied: tensorboard<2.3.0,>=2.2.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow>=1.13.1; extra == "cpu"->seqeval[cpu]) (2.2.0)
# Requirement already satisfied: gast==0.3.3 in /usr/local/lib/python3.6/dist-packages (from tensorflow>=1.13.1; extra == "cpu"->seqeval[cpu]) (0.3.3)
# Requirement already satisfied: astunparse==1.6.3 in /usr/local/lib/python3.6/dist-packages (from tensorflow>=1.13.1; extra == "cpu"->seqeval[cpu]) (1.6.3)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow>=1.13.1; extra == "cpu"->seqeval[cpu]) (0.9.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow>=1.13.1; extra == "cpu"->seqeval[cpu]) (1.1.0)
# Requirement already satisfied: protobuf>=3.8.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow>=1.13.1; extra == "cpu"->seqeval[cpu]) (3.10.0)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow>=1.13.1; extra == "cpu"->seqeval[cpu]) (1.12.1)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow>=1.13.1; extra == "cpu"->seqeval[cpu]) (1.7.2)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow>=1.13.1; extra == "cpu"->seqeval[cpu]) (1.6.0.post2)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow>=1.13.1; extra == "cpu"->seqeval[cpu]) (1.0.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow>=1.13.1; extra == "cpu"->seqeval[cpu]) (3.2.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow>=1.13.1; extra == "cpu"->seqeval[cpu]) (2.21.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow>=1.13.1; extra == "cpu"->seqeval[cpu]) (0.4.1)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow>=1.13.1; extra == "cpu"->seqeval[cpu]) (46.1.3)
# Requirement already satisfied: cachetools<3.2,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard<2.3.0,>=2.2.0->tensorflow>=1.13.1; extra == "cpu"->seqeval[cpu]) (3.1.1)
# Requirement already satisfied: rsa<4.1,>=3.1.4 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard<2.3.0,>=2.2.0->tensorflow>=1.13.1; extra == "cpu"->seqeval[cpu]) (4.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard<2.3.0,>=2.2.0->tensorflow>=1.13.1; extra == "cpu"->seqeval[cpu]) (0.2.8)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard<2.3.0,>=2.2.0->tensorflow>=1.13.1; extra == "cpu"->seqeval[cpu]) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard<2.3.0,>=2.2.0->tensorflow>=1.13.1; extra == "cpu"->seqeval[cpu]) (2019.11.28)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard<2.3.0,>=2.2.0->tensorflow>=1.13.1; extra == "cpu"->seqeval[cpu]) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard<2.3.0,>=2.2.0->tensorflow>=1.13.1; extra == "cpu"->seqeval[cpu]) (2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.3.0,>=2.2.0->tensorflow>=1.13.1; extra == "cpu"->seqeval[cpu]) (1.3.0)
# Requirement already satisfied: pyasn1>=0.1.3 in /usr/local/lib/python3.6/dist-packages (from rsa<4.1,>=3.1.4->google-auth<2,>=1.6.3->tensorboard<2.3.0,>=2.2.0->tensorflow>=1.13.1; extra == "cpu"->seqeval[cpu]) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.3.0,>=2.2.0->tensorflow>=1.13.1; extra == "cpu"->seqeval[cpu]) (3.1.0)

# %% [markdown]
# Let's run the evaluate the model on two sample files:
#
# - [answer.txt](https://www.dl.dropboxusercontent.com/s/uhzyv8ofrsoxepo/answer.txt)
# - [output.txt](https://www.dl.dropboxusercontent.com/s/7g6w12i59srqqw4/output.txt)
#
# The content of answer.txt and output.txt are as follows.
#
# answer.txt
#
# ```
# Tôi	B-W
# là	B-W
# sinh	B-W
# viên	I-W
# .	B-W
#
# Tôi	B-W
# là	B-W
# giảng	B-W
# viên	I-W
# đại	B-W
# học	I-W
# .	B-W
# ```
#
# output.txt
# ```
# Tôi	B-W
# là	B-W
# sinh	B-W
# viên	B-W
# .	B-W
#
# Tôi	B-W
# là	B-W
# giảng	B-W
# viên	B-W
# đại	B-W
# học	I-W
# .	B-W
# ```

# %% [markdown]
# #EVALUATION
#
# ##I created my own answer test because I don't know what to do with the extra line

# %%
words = ('Tôi là sinh viên . Tôi là giảng viên đại học .'.split())
tags = ('B-W B-W B-W I-W B-W B-W B-W B-W I-W B-W I-W B-W'.split())

with open('answer.txt', 'w') as fo:
    for i in range(len(words)):
        fo.write("{} {}\n".format(words[i], tags[i]))

# %%
# !cat answer.txt
# Out:
# Tôi B-W
# là B-W
# sinh B-W
# viên I-W
# . B-W
# Tôi B-W
# là B-W
# giảng B-W
# viên I-W
# đại B-W
# học I-W
# . B-W

# %%
test = ('Tôi là sinh viên . Tôi là giảng viên đại học .'.split())

with open('output.txt', 'w') as fo:
    tag = decode(test)
    for i in range(len(test)):
        fo.write("{} {}\n".format(test[i], tag[i]))

# %%
# !cat output.txt
# Out:
# Tôi B-W
# là B-W
# sinh I-W
# viên I-W
# . B-W
# Tôi B-W
# là B-W
# giảng B-W
# viên I-W
# đại B-W
# học I-W
# . B-W

# %%
from seqeval.metrics import precision_score, recall_score, f1_score

def get_tags(filepath):
    res = []
    with open(filepath, 'r') as f:
        cur_sen = []
        for line in f:
            line = line.strip()
            if line == '':
                if len(cur_sen) != 0:
                    res.append(cur_sen)
                    cur_sen = []
            else:
                word, tag = line.split()
                cur_sen.append(tag)
    if len(cur_sen) != 0:
        res.append(cur_sen)
    return res

def evaluate(test_file, output_file):
    y_true = get_tags(test_file)
    y_pred = get_tags(output_file)

    p = precision_score(y_true, y_pred)
    r = recall_score(y_true, y_pred)
    f1 = f1_score(y_true, y_pred)
    return p, r, f1

# %%
evaluate('./answer.txt', './output.txt')
# Out:
# (0.875, 0.7777777777777778, 0.823529411764706)

# %% [markdown]
# ## References
#
# - Huyen, N. T. M., Roussanaly, A., & Vinh, H. T. (2008, March). A hybrid approach to word segmentation of Vietnamese texts. In International Conference on Language and Automata Theory and Applications (pp. 240-249). Springer, Berlin, Heidelberg.
# - Nguyen, T. P., & Le, A. C. (2016, November). [A hybrid approach to Vietnamese word segmentation](https://www.researchgate.net/profile/Tuan_Phong_Nguyen/publication/311980397_A_hybrid_approach_to_Vietnamese_word_segmentation/links/5a9507e3a6fdccecff0771ff/A-hybrid-approach-to-Vietnamese-word-segmentation.pdf). In 2016 IEEE RIVF International Conference on Computing & Communication Technologies, Research, Innovation, and Vision for the Future (RIVF) (pp. 114-119). IEEE.
# - Nguyen, D. Q., Nguyen, D. Q., Vu, T., Dras, M., & Johnson, M. (2017). [A fast and accurate vietnamese word segmenter](https://arxiv.org/abs/1709.06307). arXiv preprint arXiv:1709.06307.
# - [seqeval](https://github.com/chakki-works/seqevalhttps://github.com/chakki-works/seqeval) for sequence labeling evaluation.
